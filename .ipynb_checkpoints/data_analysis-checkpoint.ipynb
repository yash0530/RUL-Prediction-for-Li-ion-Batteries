# %%
from scipy.io import loadmat
battery = 'B0005'
data = loadmat(f'DATA/{battery}.mat')

# %%
x = data[battery]["cycle"][0][0][0]
ambient_temperature = x['ambient_temperature']
type = x['type']
time = x['time']
data = x['data']

# %%
print(f'Battery: {battery}')
print(f'Cycles: {data.size}')
# Out:
# Battery: B0005
# Cycles: 616

# %%
# Example data
print(f'Ambient Temp: {ambient_temperature[0]}')
print(f'Type: {type[0]}')
print(f'Time: {time[0]}')
print('Data:')
print('\tVoltage_measured: ', data[0]['Voltage_measured'])
print('\tCurrent_measured: ', data[0]['Current_measured'])
print('\tTemperature_measured: ', data[0]['Temperature_measured'])
print('\tCurrent_charge: ', data[0]['Current_charge'])
print('\tVoltage_charge: ', data[0]['Voltage_charge'])
print('\tTime: ', data[0]['Time'])
# Out:
# Ambient Temp: [[24]]
# Type: ['charge']
# Time: [[2.0080e+03 4.0000e+00 2.0000e+00 1.3000e+01 8.0000e+00 1.7921e+01]]
# Data:
# 	Voltage_measured:  [[array([[3.87301722, 3.47939356, 4.00058782, 4.01239519, 4.01970806,
#         4.02540947, 4.03063627, 4.03534896, 4.03971637, 4.04354121,
#         4.04672407, 4.05032083, 4.05347776, 4.05687947, 4.06020401,
#         4.06309148, 4.06606364, 4.06810568, 4.07091089, 4.07314062,
#         4.07531198, 4.07798651, 4.07976022, 4.08180212, 4.08379322,
#         4.08535888, 4.08707793, 4.0888699 , 4.08991841, 4.09204117,
#         4.09327341, 4.09462341, 4.09636787, 4.09755211, 4.09852259,
#         4.09990153, 4.10107397, 4.10186053, 4.10303834, 4.10433761,
#         4.10518719, 4.10617751, 4.10713402, 4.108074  , 4.10876115,
#         4.10971157, 4.11073785, 4.1115377 , 4.11216994, 4.11307997,
#         4.11363282, 4.114555  , 4.11540239, 4.115793  , 4.11674636,
#         4.117245  , 4.11794271, 4.1186426 , 4.11943651, 4.12004755,
# ...
